# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"D:\itvedant\Vscode\ice_scream.csv")

# %%
df.head(2)
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120

# %%
df.shape
# Out:
# (49, 2)

# %%
df.isnull().sum()
# Out:
# Temperature (°C)           0
# Ice Cream Sales (units)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split

# %%
X=df[['Temperature (°C)']]
Y=df['Ice Cream Sales (units)']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
print('x_train :',x_train.shape)
print('x_test :',x_test.shape)
# Out:
# x_train : (39, 1)
# x_test : (10, 1)

# %%
x_test
# Out:
#     Temperature (°C)
# 13         -1.818938
# 45          3.704057
# 47          4.133534
# 44          3.610778
# 17         -0.773330
# 27          1.024181
# 26          0.874905
# 25          0.693599
# 31          1.850552
# 19         -0.149635

# %%
x_test.shape
# Out:
# (10, 1)

# %%
x_train.shape
# Out:
# (39, 1)

# %%
y_test.shape
# Out:
# (10,)

# %%
y_train.shape
# Out:
# (39,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# -0.5751270190188227

# %%
model.score(x_train,y_train)
# Out:
# 0.06579063815950037

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=12)

# %%
x_poly=poly.fit_transform(x_train)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test_poly=poly.fit_transform(x_test)

# %%
model.fit(x_poly,y_train)
# Out:
# LinearRegression()

# %%
x_test_poly=poly.fit_transform(x_test)

# %%
model.score(x_poly,y_train)
# Out:
# 0.9737048780482714

# %%
model.score(x_test,y_test)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 model.score(x_test,y_test)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:848, in RegressorMixin.score(self, X, y, sample_weight)
#     806 """Return the coefficient of determination of the prediction.
#     807
#     808 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     843 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     844 """
#     846 from .metrics import r2_score
# --> 848 y_pred = self.predict(X)
#     849 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 1 features, but LinearRegression is expecting 13 features as input.
